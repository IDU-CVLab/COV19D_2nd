# %% [markdown]
# ## Region based segmentation using annotated public "COVID-19 CT segmentation dataset"
#
# * The algorithm explores lung region based segmetnation.
# * The dice coeffecient was used to measure the preformance of the segmetnation method.
# * The annotated CT images at http://medicalsegmentation.com/covid19/
# was used.
# * From the annotated dataset: the Image volumes (308 Mb), and the Lung masks (1 Mb) were used to validate the segmentaiton performacne.

# %%
import os, glob
import numpy as np
import matplotlib.pyplot as plt
import cv2
import nibabel as nib

import tensorflow as tf
 
from tensorflow import keras

# %%
from PIL import Image as im
import skimage
from skimage.filters import sobel

# %%
from skimage import morphology
from skimage.feature import canny
#from scipy import ndimage as ndi
from skimage import io
from skimage.exposure import histogram

# %%
# Mounting my google drive
from google.colab import drive

# %%
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Slicing and Saving

# %%
## The path here include the image volumes (308MB) and the lung masks (1MB) were extracted from the COVID-19 CT segmentation dataset
dataInputPath = '/content/gdrive/MyDrive/Segmentation/volumes/'
imagePathInput = os.path.join(dataInputPath, 'img/') ## Image volumes were exctracted to this subfolder
maskPathInput = os.path.join(dataInputPath, 'mask/') ## lung masks were exctracted to this subfolder

# %%
# Preparing the outputpath for slicing the CT volume from the above data
dataOutputPath = '/content/gdrive/MyDrive/Segmentation/slices/'
imageSliceOutput = os.path.join(dataOutputPath, 'img/') ## Image volume slices will be placed here
maskSliceOutput = os.path.join(dataOutputPath, 'mask/') ## Annotated masks slices will be placed here

# %%
# Slicing only in Z direction
# Slices in Z direction shows the required lung area
SLICE_X = False
SLICE_Y = False
SLICE_Z = True

SLICE_DECIMATE_IDENTIFIER = 3

# %%
# Choosing normalization boundaries suitable from the chosen images
HOUNSFIELD_MIN = -1020
HOUNSFIELD_MAX = 2995
HOUNSFIELD_RANGE = HOUNSFIELD_MAX - HOUNSFIELD_MIN

# Normalizing the images
def normalizeImageIntensityRange (img):
    img[img < HOUNSFIELD_MIN] = HOUNSFIELD_MIN
    img[img > HOUNSFIELD_MAX] = HOUNSFIELD_MAX
    return (img - HOUNSFIELD_MIN) / HOUNSFIELD_RANGE

nImg = normalizeImageIntensityRange(img)
np.min(nImg), np.max(nImg), nImg.shape, type(nImg)

# Reading image or mask volume
def readImageVolume(imgPath, normalize=True):
    img = nib.load(imgPath).get_fdata()
    if normalize:
        return normalizeImageIntensityRange(img)
    else:
        return img
    
readImageVolume(imgPath, normalize=False)
readImageVolume(maskPath, normalize=False)

# Slicing image in all directions and save
def sliceAndSaveVolumeImage(vol, fname, path):
    (dimx, dimy, dimz) = vol.shape
    print(dimx, dimy, dimz)
    cnt = 0
    if SLICE_X:
        cnt += dimx
        print('Slicing X: ')
        for i in range(dimx):
            saveSlice(vol[i,:,:], fname+f'-slice{str(i).zfill(SLICE_DECIMATE_IDENTIFIER)}_x', path)
            
    if SLICE_Y:
        cnt += dimy
        print('Slicing Y: ')
        for i in range(dimy):
            saveSlice(vol[:,i,:], fname+f'-slice{str(i).zfill(SLICE_DECIMATE_IDENTIFIER)}_y', path)
            
    if SLICE_Z:
        cnt += dimz
        print('Slicing Z: ')
        for i in range(dimz):
            saveSlice(vol[:,:,i], fname+f'-slice{str(i).zfill(SLICE_DECIMATE_IDENTIFIER)}_z', path)
    return cnt

# Saving volume slices to file
def saveSlice (img, fname, path):
    img = np.uint8(img * 255)
    fout = os.path.join(path, f'{fname}.png')
    cv2.imwrite(fout, img)
    print(f'[+] Slice saved: {fout}', end='\r')

# %%
# Reading and processing image volumes for TEST images
for index, filename in enumerate(sorted(glob.iglob(imagePathInput+'*.nii.gz'))):
    img = readImageVolume(filename, True)
    print(filename, img.shape, np.sum(img.shape), np.min(img), np.max(img))
    numOfSlices = sliceAndSaveVolumeImage(img, 't'+str(index), imageSliceOutput)
    print(f'\n{filename}, {numOfSlices} slices created \n')

# Reading and processing image mask volumes for TEST masks
for index, filename in enumerate(sorted(glob.iglob(maskPathInput+'*.nii.gz'))):
    img = readImageVolume(filename, False)
    print(filename, img.shape, np.sum(img.shape), np.min(img), np.max(img))
    numOfSlices = sliceAndSaveVolumeImage(img, 't'+str(index), maskSliceOutput)
    print(f'\n{filename}, {numOfSlices} slices created \n')
# Out:
# /content/gdrive/MyDrive/Segmentation/volumes/img/1.nii.gz (630, 630, 45) 1305 0.0 0.3070329411982896
# 630 630 45
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t0-slice044_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/1.nii.gz, 45 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/2.nii.gz (630, 630, 39) 1299 0.0 0.29788061310612546
# 630 630 39
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t1-slice038_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/2.nii.gz, 39 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/3.nii.gz (630, 630, 418) 1678 0.0 0.28805189310836316
# 630 630 418
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t2-slice417_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/3.nii.gz, 418 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/4.nii.gz (630, 630, 39) 1299 0.0 0.29359098175542886
# 630 630 39
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t3-slice038_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/4.nii.gz, 39 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/5.nii.gz (630, 630, 66) 1326 0.0 0.29295800233985836
# 630 630 66
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t4-slice065_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/5.nii.gz, 66 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/6.nii.gz (630, 630, 42) 1302 0.0 0.29983340746735876
# 630 630 42
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t5-slice041_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/6.nii.gz, 42 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/7.nii.gz (630, 630, 42) 1302 0.0 0.29788061310612546
# 630 630 42
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t6-slice041_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/7.nii.gz, 42 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/8.nii.gz (630, 630, 45) 1305 0.0 0.3115153501517746
# 630 630 45
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t7-slice044_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/8.nii.gz, 45 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/img/9.nii.gz (630, 630, 93) 1353 0.0 0.3265356840558842
# 630 630 93
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/img/t8-slice092_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/img/9.nii.gz, 93 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/1.nii.gz (630, 630, 45) 1305 0.0 1.0
# 630 630 45
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t0-slice044_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/1.nii.gz, 45 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/2.nii.gz (630, 630, 39) 1299 0.0 1.0
# 630 630 39
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t1-slice038_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/2.nii.gz, 39 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/3.nii.gz (630, 630, 418) 1678 0.0 1.0
# 630 630 418
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t2-slice417_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/3.nii.gz, 418 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/4.nii.gz (630, 630, 39) 1299 0.0 1.0
# 630 630 39
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t3-slice038_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/4.nii.gz, 39 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/5.nii.gz (630, 630, 66) 1326 0.0 1.0
# 630 630 66
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t4-slice065_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/5.nii.gz, 66 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/6.nii.gz (630, 630, 42) 1302 0.0 1.0
# 630 630 42
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t5-slice041_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/6.nii.gz, 42 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/7.nii.gz (630, 630, 42) 1302 0.0 1.0
# 630 630 42
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t6-slice041_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/7.nii.gz, 42 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/8.nii.gz (630, 630, 45) 1305 0.0 1.0
# 630 630 45
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t7-slice044_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/8.nii.gz, 45 slices created
#
# /content/gdrive/MyDrive/Segmentation/volumes/mask/9.nii.gz (630, 630, 93) 1353 0.0 1.0
# 630 630 93
# Slicing Z:
# [+] Slice saved: /content/gdrive/MyDrive/Segmentation/slices/mask/t8-slice092_z.png
# /content/gdrive/MyDrive/Segmentation/volumes/mask/9.nii.gz, 93 slices created

# %%
# Exploring the data 
imgPath = os.path.join(imagePathInput, '1.nii.gz')
img = nib.load(imgPath).get_fdata()
np.min(img), np.max(img), img.shape, type(img)


maskPath = os.path.join(maskPathInput, '1.nii.gz')
mask = nib.load(maskPath).get_fdata()
np.min(mask), np.max(mask), mask.shape, type(mask)

# Showing image slice
imgSlice = mask[:,:,20]
plt.imshow(imgSlice, cmap='gray')
plt.show()

# %% [markdown]
# ## Histogram based Thresholding Segmentation

# %%
## Reading the image in gray scale and gussian blurring
n= cv2.imread("/content/gdrive/MyDrive/Segmentation/slices/img/t0-slice008_z.png")
n= cv2.cvtColor(n, cv2.COLOR_BGR2GRAY)
n = cv2.GaussianBlur(n, (5, 5), 0)

# Checking image histogram for extreme values to be used as markers later 5&70
hist, hist_centers = histogram(n)

fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].imshow(n, cmap=plt.cm.gray)
axes[0].axis('off')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('histogram of gray values')

# Finding Histogram Threshold

# Otsu Method
ret, img = cv2.threshold(n, 35, 80, cv2.THRESH_BINARY + 
                                            cv2.THRESH_OTSU)
 # Manual Threshold
t = 35

fig, axes = plt.subplots(1, 2, figsize=(8, 3), sharey=True)
axes[0].imshow(n > t, cmap=plt.cm.gray)
axes[0].set_title('Manual Thresholding')

axes[1].imshow(img, cmap=plt.cm.gray)
axes[1].set_title('Outsu Thresholding')
for a in axes:
    a.axis('off')

plt.tight_layout()

# %% [markdown]
# ## Usng Otsu's Thresholding Method

# %%
# Morphological Operation
img = cv2.erode(img, None, iterations=2)
img = cv2.dilate(img, None, iterations=2)

segmentation_coins = img

fig, ax = plt.subplots(figsize=(4, 3))
ax.imshow(segmentation_coins, cmap=plt.cm.gray)
ax.set_title('removing small objects')
ax.axis('off')

# Modifying the background to exctract the segmetned lungs
ret, gray = ret, gray = cv2.threshold(segmentation_coins.astype(np.uint8), 1, 255, cv2.THRESH_BINARY)
for x in range(gray.shape[1]):
    # Fill dark top pixels:
 if gray[0, x] == 0:
      cv2.floodFill(gray, None, seedPoint=(x, 0), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color
    # Fill dark bottom pixels:
 if gray[-1, x] == 0:
      cv2.floodFill(gray, None, seedPoint=(x, gray.shape[0]-1), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color

for y in range(gray.shape[0]):
    # Fill dark left side pixels:
 if gray[y, 0] == 0:
      cv2.floodFill(gray, None, seedPoint=(0, y), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color
    # Fill dark right side pixels:
 if gray[y, -1] == 0:
      cv2.floodFill(gray, None, seedPoint=(gray.shape[1]-1, y), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color

fig, ax = plt.subplots()
plt.imshow(gray, cmap='gray')
ax.set_title('segmented Lungs')
plt.show()

# %% [markdown]
# ## Replacing images with their segmented slices in the directory

# %%
## The images in the "/content/gdrive/MyDrive/Segmentation/slices/img/*.png" will be replaced by their masks via region based segmetnation

for m in glob.glob("/content/gdrive/MyDrive/Segmentation/slices/img/*.png"):
    n=cv2.imread(m)
    n= cv2.cvtColor(n, cv2.COLOR_BGR2GRAY)
    n = cv2.GaussianBlur(n, (5, 5), 0)

    # Otsu Method
    ret, img = cv2.threshold(n, 35, 80, cv2.THRESH_BINARY + 
                                            cv2.THRESH_OTSU)
  
    img = cv2.erode(img, None, iterations=2)
    img = cv2.dilate(img, None, iterations=2)

    segmentation_coins = img

    
    # Modifying the background to exctract the segmetned lungs
    ret, gray = ret, gray = cv2.threshold(segmentation_coins.astype(np.uint8), 1, 255, cv2.THRESH_BINARY)
    for x in range(gray.shape[1]):
    # Fill dark top pixels:
     if gray[0, x] == 0:
      cv2.floodFill(gray, None, seedPoint=(x, 0), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color
    # Fill dark bottom pixels:
     if gray[-1, x] == 0:
      cv2.floodFill(gray, None, seedPoint=(x, gray.shape[0]-1), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color

    for y in range(gray.shape[0]):
    # Fill dark left side pixels:
     if gray[y, 0] == 0:
      cv2.floodFill(gray, None, seedPoint=(0, y), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color
    # Fill dark right side pixels:
     if gray[y, -1] == 0:
      cv2.floodFill(gray, None, seedPoint=(gray.shape[1]-1, y), newVal=255, loDiff=3, upDiff=3)  # Fill the background with white color
    
    file_name, file_ext = os.path.splitext(m)
    gray = im.fromarray(gray)
    gray.save('{}.png'.format(file_name))

# %% [markdown]
# ## Using Dice Coeffecient for measuring the perforrmamce of the Segmentation

# %%
## Segmetnation Quantifying Measure (Dice coeffecient)

def dice_coef(img, img2):
        if img.shape != img2.shape:
            raise ValueError("Shape mismatch: img and img2 must have to be of the same shape.")
        else:
            
            lenIntersection=0
            
            for i in range(img.shape[0]):
                for j in range(img.shape[1]):
                    if ( np.array_equal(img[i][j],img2[i][j]) ):
                        lenIntersection+=1
             
            lenimg=img.shape[0]*img.shape[1]
            lenimg2=img2.shape[0]*img2.shape[1]  
            value = (2. * lenIntersection  / (lenimg + lenimg2))
        return value

# %%
## Ground Truth Mask
img = cv2.imread('/content/gdrive/MyDrive/Segmentation/slices/mask/t0-slice012_z.png')

hist, hist_centers = histogram(img)
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].imshow(img, cmap=plt.cm.gray)
axes[0].axis('off')
axes[0].set_title('Ground Truth')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('Ground Truth Grey Values')

#print(img)
img = np.asarray(img).astype(np.bool)
#print(img)
print(img.shape)
#print('_'*40)

## Predicted mask
img2 = cv2.imread('/content/gdrive/MyDrive/Segmentation/slices/img/t0-slice012_z.png')
img2 = cv2.subtract(250, img2)

hist, hist_centers = histogram(img2)
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].imshow(img2, cmap=plt.cm.gray)
axes[0].axis('off')
axes[0].set_title('Predicted Mask')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('Pridited mask Grey Values')

#print(img2)
img2 = np.asarray(img2).astype(np.bool)

#print(img2)
print(img2.shape)
#print('%'*40)

value = dice_coef(img, img2)
print("Dice coeffecient value is", value)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# (630, 630, 3)
# (630, 630, 3)
# Dice coeffecient value is 0.8575258251448727

# %%
## Checking Dice values for all slices in the dataset (image volumes and lung musks)
GT_path = '/content/gdrive/MyDrive/Segmentation/slices/mask/'
pred_path = '/content/gdrive/MyDrive/Segmentation/slices/img/'

import os

# specify the img directory path
path = "path/to/img/folder/"

# list files in img directory
files = os.listdir(GT_path)
files2 = os.listdir(pred_path)

dicee = []
for file in files:
    # make sure file is an image
    if file.endswith('.png'):
      for filee in files2:
        if filee == file:
          ## Ground Truth Mask
          img = cv2.imread(GT_path + file)
          img = np.asarray(img).astype(np.bool)

          ## Predicted mask
          img2 = cv2.imread(pred_path + filee)
          img2 = cv2.subtract(250, img2)
          img2 = np.asarray(img2).astype(np.bool)

          value = dice_coef(img, img2)
          print("Dice coeffecient value is", value, "\n") 
          dicee.append(value)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Dice coeffecient value is 0.9780120937263794
#
# Dice coeffecient value is 0.9924162257495591
#
# Dice coeffecient value is 0.9630561854371378
#
# Dice coeffecient value is 0.9503174603174603
#
# Dice coeffecient value is 0.8445074326026707
#
# Dice coeffecient value is 0.9359712773998489
#
# Dice coeffecient value is 0.8396649029982364
#
# Dice coeffecient value is 0.8437314184933232
#
# Dice coeffecient value is 0.8399874023683548
#
# Dice coeffecient value is 0.8396951373141849
#
# Dice coeffecient value is 0.8411211892164273
#
# Dice coeffecient value is 0.8427916351725876
#
# Dice coeffecient value is 0.8418241370622322
#
# Dice coeffecient value is 0.8412144116906022
#
# Dice coeffecient value is 0.8409095490047871
#
# Dice coeffecient value is 0.8392869740488789
#
# Dice coeffecient value is 0.8432980599647266
#
# Dice coeffecient value is 0.833514739229025
#
# Dice coeffecient value is 0.8346535651297556
#
# Dice coeffecient value is 0.8316200554295793
#
# Dice coeffecient value is 0.8293247669438145
#
# Dice coeffecient value is 0.8256160241874527
#
# Dice coeffecient value is 0.8281002771478962
#
# Dice coeffecient value is 0.8205593348450492
#
# Dice coeffecient value is 0.8340816326530612
#
# Dice coeffecient value is 0.84854119425548
#
# Dice coeffecient value is 0.8214134542705971
#
# Dice coeffecient value is 0.9448450491307634
#
# Dice coeffecient value is 0.8170622323003275
#
# Dice coeffecient value is 0.9119652305366591
#
# Dice coeffecient value is 0.8857218442932728
#
# Dice coeffecient value is 0.8644520030234316
#
# Dice coeffecient value is 0.9615394305870496
#
# Dice coeffecient value is 0.9969085411942554
#
# Dice coeffecient value is 0.9936079617031998
#
# Dice coeffecient value is 0.9667724867724867
#
# Dice coeffecient value is 0.9758453010833963
#
# Dice coeffecient value is 0.9919904257999496
#
# Dice coeffecient value is 0.9920508944318468
#
# Dice coeffecient value is 0.9962484252960443
#
# Dice coeffecient value is 0.9811942554799697
#
# Dice coeffecient value is 0.952111363063744
#
# Dice coeffecient value is 0.9954572940287226
#
# Dice coeffecient value is 0.9246157722348198
#
# Dice coeffecient value is 0.8845099521289997
#
# Dice coeffecient value is 0.8480826404635928
#
# Dice coeffecient value is 0.8108742756361804
#
# Dice coeffecient value is 0.789095490047871
#
# Dice coeffecient value is 0.7934013605442177
#
# Dice coeffecient value is 0.7971630133534895
#
# Dice coeffecient value is 0.7993701184177374
#
# Dice coeffecient value is 0.7910707986898463
#
# Dice coeffecient value is 0.7937641723356009
#
# Dice coeffecient value is 0.8002040816326531
#
# Dice coeffecient value is 0.802968002015621
#
# Dice coeffecient value is 0.8071554547745023
#
# Dice coeffecient value is 0.8032023179642227
#
# Dice coeffecient value is 0.8139002267573696
#
# Dice coeffecient value is 0.839244142101285
#
# Dice coeffecient value is 0.8219879062736205
#
# Dice coeffecient value is 0.8451801461325271
#
# Dice coeffecient value is 0.831254724111867
#
# Dice coeffecient value is 0.8557671957671957
#
# Dice coeffecient value is 0.8695112118921643
#
# Dice coeffecient value is 0.8854421768707483
#
# Dice coeffecient value is 0.90140589569161
#
# Dice coeffecient value is 0.922058453010834
#
# Dice coeffecient value is 0.9434139581758629
#
# Dice coeffecient value is 0.9586142605190224
#
# Dice coeffecient value is 0.9712471655328798
#
# Dice coeffecient value is 0.9870068027210884
#
# Dice coeffecient value is 0.9984983623078861
#
# Dice coeffecient value is 0.998442932728647
#
# Dice coeffecient value is 0.9982716049382716
#
# Dice coeffecient value is 0.9920156210632401
#
# Dice coeffecient value is 0.9919223985890653
#
# Dice coeffecient value is 0.992060972537163
#
# Dice coeffecient value is 0.9919576719576719
#
# Dice coeffecient value is 0.991809019904258
#
# Dice coeffecient value is 0.992761400856639
#
# Dice coeffecient value is 0.9920559334845049
#
# Dice coeffecient value is 0.9923683547493072
#
# Dice coeffecient value is 0.9929503653313178
#
# Dice coeffecient value is 0.9932426303854875
#
# Dice coeffecient value is 0.9937767699672462
#
# Dice coeffecient value is 0.9942151675485009
#
# Dice coeffecient value is 0.9946812799193752
#
# Dice coeffecient value is 0.9951171579743008
#
# Dice coeffecient value is 0.9949181153943059
#
# Dice coeffecient value is 0.9953842277651801
#
# Dice coeffecient value is 0.9956210632401109
#
# Dice coeffecient value is 0.9958856135046611
#
# Dice coeffecient value is 0.9960443436633912
#
# Dice coeffecient value is 0.9963895187704711
#
# Dice coeffecient value is 0.996581002771479
#
# Dice coeffecient value is 0.9967825648778029
#
# Dice coeffecient value is 0.9971000251952633
#
# Dice coeffecient value is 0.9967271352985638
#
# Dice coeffecient value is 0.9958931720836482
#
# Dice coeffecient value is 0.9965180146132527
#
# Dice coeffecient value is 0.9961199294532628
#
# Dice coeffecient value is 0.9962131519274376
#
# Dice coeffecient value is 0.9956084656084656
#
# Dice coeffecient value is 0.994928193499622
#
# Dice coeffecient value is 0.9944948349710254
#
# Dice coeffecient value is 0.9954043839758125
#
# Dice coeffecient value is 0.9936104812295289
#
# Dice coeffecient value is 0.9928974552784077
#
# Dice coeffecient value is 0.9910330057949106
#
# Dice coeffecient value is 0.9920534139581758
#
# Dice coeffecient value is 0.9913781809019905
#
# Dice coeffecient value is 0.9897077349458302
#
# Dice coeffecient value is 0.9903073822121441
#
# Dice coeffecient value is 0.9881380700428319
#
# Dice coeffecient value is 0.9887326782564878
#
# Dice coeffecient value is 0.9892340639959688
#
# Dice coeffecient value is 0.9875560594608214
#
# Dice coeffecient value is 0.9854472159234064
#
# Dice coeffecient value is 0.9863744016124969
#
# Dice coeffecient value is 0.9843235071806501
#
# Dice coeffecient value is 0.9824464600655077
#
# Dice coeffecient value is 0.9808314436885865
#
# Dice coeffecient value is 0.9788057445200302
#
# Dice coeffecient value is 0.9572260015117158
#
# Dice coeffecient value is 0.9627034517510707
#
# Dice coeffecient value is 0.9728017132779038
#
# Dice coeffecient value is 0.9768178382464097
#
# Dice coeffecient value is 0.9651625094482237
#
# Dice coeffecient value is 0.9678659611992946
#
# Dice coeffecient value is 0.9599017384731671
#
# Dice coeffecient value is 0.970498866213152
#
# Dice coeffecient value is 0.9748324514991181
#
# Dice coeffecient value is 0.9545956160241874
#
# Dice coeffecient value is 0.9444192491811539
#
# Dice coeffecient value is 0.9419375157470395
#
# Dice coeffecient value is 0.946787603930461
#
# Dice coeffecient value is 0.9395086923658352
#
# Dice coeffecient value is 0.9493348450491308
#
# Dice coeffecient value is 0.9518820861678005
#
# Dice coeffecient value is 0.9370219198790627
#
# Dice coeffecient value is 0.9340992693373645
#
# Dice coeffecient value is 0.9315343915343915
#
# Dice coeffecient value is 0.9286318972033257
#
# Dice coeffecient value is 0.8948148148148148
#
# Dice coeffecient value is 0.9137944066515495
#
# Dice coeffecient value is 0.8988662131519274
#
# Dice coeffecient value is 0.9029528848576468
#
# Dice coeffecient value is 0.9100554295792391
#
# Dice coeffecient value is 0.9265709246661628
#
# Dice coeffecient value is 0.9204938271604939
#
# Dice coeffecient value is 0.9237717309145881
#
# Dice coeffecient value is 0.906734693877551
#
# Dice coeffecient value is 0.9158478206097254
#
# Dice coeffecient value is 0.8909800957420005
#
# Dice coeffecient value is 0.8865558075081884
#
# Dice coeffecient value is 0.8809952128999748
#
# Dice coeffecient value is 0.8590224237843286
#
# Dice coeffecient value is 0.8635474930713026
#
# Dice coeffecient value is 0.8549407911312673
#
# Dice coeffecient value is 0.8715545477450239
#
# Dice coeffecient value is 0.8503224993701184
#
# Dice coeffecient value is 0.8765583270345175
#
# Dice coeffecient value is 0.8676492819349962
#
# Dice coeffecient value is 0.8209145880574452
#
# Dice coeffecient value is 0.8152355757117662
#
# Dice coeffecient value is 0.8420332577475435
#
# Dice coeffecient value is 0.8227311665406903
#
# Dice coeffecient value is 0.8334114386495339
#
# Dice coeffecient value is 0.8167472915091962
#
# Dice coeffecient value is 0.8191786344167297
#
# Dice coeffecient value is 0.8289241622574955
#
# Dice coeffecient value is 0.8378206097253716
#
# Dice coeffecient value is 0.8466288737717309
#
# Dice coeffecient value is 0.8130763416477702
#
# Dice coeffecient value is 0.8108289241622575
#
# Dice coeffecient value is 0.8094331065759637
#
# Dice coeffecient value is 0.8064676240866717
#
# Dice coeffecient value is 0.8045779793398841
#
# Dice coeffecient value is 0.807538422776518
#
# Dice coeffecient value is 0.8020156210632401
#
# Dice coeffecient value is 0.7984303350970018
#
# Dice coeffecient value is 0.8001738473167045
#
# Dice coeffecient value is 0.8030234315948601
#
# Dice coeffecient value is 0.7958453010833964
#
# Dice coeffecient value is 0.7925321239606954
#
# Dice coeffecient value is 0.7892567397329302
#
# Dice coeffecient value is 0.7905240614764424
#
# Dice coeffecient value is 0.7944570420760897
#
# Dice coeffecient value is 0.7891609977324263
#
# Dice coeffecient value is 0.789145880574452
#
# Dice coeffecient value is 0.7890400604686318
#
# Dice coeffecient value is 0.7891584782060973
#
# Dice coeffecient value is 0.788994708994709
#
# Dice coeffecient value is 0.7897178130511464
#
# Dice coeffecient value is 0.7894331065759638
#
# Dice coeffecient value is 0.7896749811035525
#
# Dice coeffecient value is 0.7895817586293776
#
# Dice coeffecient value is 0.7888788107835727
#
# Dice coeffecient value is 0.7889569160997733
#
# Dice coeffecient value is 0.7888737717309146
#
# Dice coeffecient value is 0.7890148652053414
#
# Dice coeffecient value is 0.7889644746787604
#
# Dice coeffecient value is 0.7891584782060973
#
# Dice coeffecient value is 0.793363567649282
#
# Dice coeffecient value is 0.7904686318972033
#
# Dice coeffecient value is 0.7909019904257999
#
# Dice coeffecient value is 0.7912975560594608
#
# Dice coeffecient value is 0.7917132779037541
#
# Dice coeffecient value is 0.793116654069035
#
# Dice coeffecient value is 0.7922675736961451
#
# Dice coeffecient value is 0.7927311665406903
#
# Dice coeffecient value is 0.7900075585789872
#
# Dice coeffecient value is 0.793567649281935
#
# Dice coeffecient value is 0.793869992441421
#
# Dice coeffecient value is 0.7945049130763416
#
# Dice coeffecient value is 0.7946636432350718
#
# Dice coeffecient value is 0.7946863189720332
#
# Dice coeffecient value is 0.7940866717057193
#
# Dice coeffecient value is 0.794620811287478
#
# Dice coeffecient value is 0.7942454018644495
#
# Dice coeffecient value is 0.7945880574452003
#
# Dice coeffecient value is 0.7959032501889645
#
# Dice coeffecient value is 0.796029226505417
#
# Dice coeffecient value is 0.7972738725119678
#
# Dice coeffecient value is 0.7981607457797933
#
# Dice coeffecient value is 0.7989216427311665
#
# Dice coeffecient value is 0.7986167800453515
#
# Dice coeffecient value is 0.7980876795162509
#
# Dice coeffecient value is 0.7978231292517007
#
# Dice coeffecient value is 0.7985966238347191
#
# Dice coeffecient value is 0.7986318972033257
#
# Dice coeffecient value is 0.7986671705719325
#
# Dice coeffecient value is 0.7987226001511716
#
# Dice coeffecient value is 0.7992088687326783
#
# Dice coeffecient value is 0.8004257999496095
#
# Dice coeffecient value is 0.8005291005291005
#
# Dice coeffecient value is 0.8015192743764172
#
# Dice coeffecient value is 0.8024237843285462
#
# Dice coeffecient value is 0.8022222222222222
#
# Dice coeffecient value is 0.8019349962207105
#
# Dice coeffecient value is 0.8022726127488032
#
# Dice coeffecient value is 0.8025976316452507
#
# Dice coeffecient value is 0.8024993701184178
#
# Dice coeffecient value is 0.8022978080120937
#
# Dice coeffecient value is 0.8025472411186697
#
# Dice coeffecient value is 0.8029100529100529
#
# Dice coeffecient value is 0.8036659108087679
#
# Dice coeffecient value is 0.8041798941798942
#
# Dice coeffecient value is 0.8043764172335601
#
# Dice coeffecient value is 0.8044091710758378
#
# Dice coeffecient value is 0.8043915343915344
#
# Dice coeffecient value is 0.804726631393298
#
# Dice coeffecient value is 0.8055404383975813
#
# Dice coeffecient value is 0.8050415721844293
#
# Dice coeffecient value is 0.8055102040816327
#
# Dice coeffecient value is 0.8037238599143361
#
# Dice coeffecient value is 0.8051877047115142
#
# Dice coeffecient value is 0.8056336608717561
#
# Dice coeffecient value is 0.8057722348198538
#
# Dice coeffecient value is 0.8055454774502393
#
# Dice coeffecient value is 0.8063038548752834
#
# Dice coeffecient value is 0.8066691861929958
#
# Dice coeffecient value is 0.8068909045099522
#
# Dice coeffecient value is 0.8075585789871504
#
# Dice coeffecient value is 0.8077122700932224
#
# Dice coeffecient value is 0.8076694381456286
#
# Dice coeffecient value is 0.8076643990929705
#
# Dice coeffecient value is 0.8070194003527337
#
# Dice coeffecient value is 0.8072738725119678
#
# Dice coeffecient value is 0.8069009826152683
#
# Dice coeffecient value is 0.8068682287729907
#
# Dice coeffecient value is 0.8065658856135046
#
# Dice coeffecient value is 0.8068405139833711
#
# Dice coeffecient value is 0.8072486772486772
#
# Dice coeffecient value is 0.8090274628369867
#
# Dice coeffecient value is 0.8108969513731419
#
# Dice coeffecient value is 0.8112471655328798
#
# Dice coeffecient value is 0.8113202317964223
#
# Dice coeffecient value is 0.812567397329302
#
# Dice coeffecient value is 0.8113731418493323
#
# Dice coeffecient value is 0.8125396825396826
#
# Dice coeffecient value is 0.813114134542706
#
# Dice coeffecient value is 0.8125195263290501
#
# Dice coeffecient value is 0.8124489795918367
#
# Dice coeffecient value is 0.8125044091710758
#
# Dice coeffecient value is 0.8132224741748552
#
# Dice coeffecient value is 0.8142277651801462
#
# Dice coeffecient value is 0.8143260267069791
#
# Dice coeffecient value is 0.8143890148652053
#
# Dice coeffecient value is 0.8152884857646763
#
# Dice coeffecient value is 0.8147316704459562
#
# Dice coeffecient value is 0.8159637188208617
#
# Dice coeffecient value is 0.8166490299823633
#
# Dice coeffecient value is 0.8174779541446208
#
# Dice coeffecient value is 0.8181657848324515
#
# Dice coeffecient value is 0.8189543965734442
#
# Dice coeffecient value is 0.8197530864197531
#
# Dice coeffecient value is 0.821559586797682
#
# Dice coeffecient value is 0.8220886873267825
#
# Dice coeffecient value is 0.8215948601662887
#
# Dice coeffecient value is 0.8206399596875787
#
# Dice coeffecient value is 0.822214663643235
#
# Dice coeffecient value is 0.8234416729654825
#
# Dice coeffecient value is 0.8244142101284958
#
# Dice coeffecient value is 0.8254598135550516
#
# Dice coeffecient value is 0.826936255983875
#
# Dice coeffecient value is 0.8261123708742756
#
# Dice coeffecient value is 0.827838246409675
#
# Dice coeffecient value is 0.8281657848324515
#
# Dice coeffecient value is 0.8291609977324264
#
# Dice coeffecient value is 0.8301259763164525
#
# Dice coeffecient value is 0.8323280423280424
#
# Dice coeffecient value is 0.8311791383219954
#
# Dice coeffecient value is 0.832257495590829
#
# Dice coeffecient value is 0.8340337616528093
#
# Dice coeffecient value is 0.8339279415469891
#
# Dice coeffecient value is 0.8334895439657345
#
# Dice coeffecient value is 0.8342579994960947
#
# Dice coeffecient value is 0.834625850340136
#
# Dice coeffecient value is 0.8366943814562863
#
# Dice coeffecient value is 0.8356916099773243
#
# Dice coeffecient value is 0.8376442428823381
#
# Dice coeffecient value is 0.8382438901486521
#
# Dice coeffecient value is 0.8393298059964727
#
# Dice coeffecient value is 0.8409750566893424
#
# Dice coeffecient value is 0.840246913580247
#
# Dice coeffecient value is 0.8410430839002268
#
# Dice coeffecient value is 0.841604938271605
#
# Dice coeffecient value is 0.8420357772738725
#
# Dice coeffecient value is 0.84140589569161
#
# Dice coeffecient value is 0.8422524565381708
#
# Dice coeffecient value is 0.8429730410682792
#
# Dice coeffecient value is 0.8434920634920635
#
# Dice coeffecient value is 0.8443184681279919
#
# Dice coeffecient value is 0.8450516502897455
#
# Dice coeffecient value is 0.8458402620307383
#
# Dice coeffecient value is 0.8465154950869237
#
# Dice coeffecient value is 0.8473444192491811
#
# Dice coeffecient value is 0.8481153943058705
#
# Dice coeffecient value is 0.8506752330561854
#
# Dice coeffecient value is 0.8499420508944319
#
# Dice coeffecient value is 0.84904509952129
#
# Dice coeffecient value is 0.8515747039556564
#
# Dice coeffecient value is 0.8524313429075334
#
# Dice coeffecient value is 0.8534920634920635
#
# Dice coeffecient value is 0.8546611237087428
#
# Dice coeffecient value is 0.8569992441421013
#
# Dice coeffecient value is 0.8557394809775762
#
# Dice coeffecient value is 0.8581809019904258
#
# Dice coeffecient value is 0.8594104308390023
#
# Dice coeffecient value is 0.8606273620559335
#
# Dice coeffecient value is 0.8631216931216931
#
# Dice coeffecient value is 0.8619223985890653
#
# Dice coeffecient value is 0.86432350718065
#
# Dice coeffecient value is 0.8657394809775762
#
# Dice coeffecient value is 0.866986646510456
#
# Dice coeffecient value is 0.8697203325774754
#
# Dice coeffecient value is 0.8684227765180146
#
# Dice coeffecient value is 0.871002771478962
#
# Dice coeffecient value is 0.8723834719072814
#
# Dice coeffecient value is 0.8737994457042076
#
# Dice coeffecient value is 0.8753061224489795
#
# Dice coeffecient value is 0.8767145376669186
#
# Dice coeffecient value is 0.8827336860670194
#
# Dice coeffecient value is 0.8812219702695894
#
# Dice coeffecient value is 0.8797304106827917
#
# Dice coeffecient value is 0.8782464096749811
#
# Dice coeffecient value is 0.8911363063744017
#
# Dice coeffecient value is 0.8870395565633661
#
# Dice coeffecient value is 0.8855580750818846
#
# Dice coeffecient value is 0.8897253716301335
#
# Dice coeffecient value is 0.8884278155706727
#
# Dice coeffecient value is 0.8926303854875284
#
# Dice coeffecient value is 0.8969715293524817
#
# Dice coeffecient value is 0.8939783320735701
#
# Dice coeffecient value is 0.9031494079113127
#
# Dice coeffecient value is 0.8999949609473419
#
# Dice coeffecient value is 0.8985361552028218
#
# Dice coeffecient value is 0.8955253212396069
#
# Dice coeffecient value is 0.9015923406399596
#
# Dice coeffecient value is 0.9048626858150668
#
# Dice coeffecient value is 0.8841773746535652
#
# Dice coeffecient value is 0.9175736961451247
#
# Dice coeffecient value is 0.9157168052406147
#
# Dice coeffecient value is 0.9084152179390275
#
# Dice coeffecient value is 0.9120408163265306
#
# Dice coeffecient value is 0.9138019652305367
#
# Dice coeffecient value is 0.9102292768959436
#
# Dice coeffecient value is 0.919546485260771
#
# Dice coeffecient value is 0.9213983371126229
#
# Dice coeffecient value is 0.9066817838246409
#
# Dice coeffecient value is 0.923416477702192
#
# Dice coeffecient value is 0.9315847820609725
#
# Dice coeffecient value is 0.9354043839758125
#
# Dice coeffecient value is 0.9334769463340892
#
# Dice coeffecient value is 0.939095490047871
#
# Dice coeffecient value is 0.9295338876291257
#
# Dice coeffecient value is 0.9372789115646258
#
# Dice coeffecient value is 0.9274653565129756
#
# Dice coeffecient value is 0.9253413958175863
#
# Dice coeffecient value is 0.9426026706979088
#
# Dice coeffecient value is 0.9409145880574452
#
# Dice coeffecient value is 0.9443058704963467
#
# Dice coeffecient value is 0.9502947845804989
#
# Dice coeffecient value is 0.9473796926177879
#
# Dice coeffecient value is 0.9515973796926178
#
# Dice coeffecient value is 0.9458553791887125
#
# Dice coeffecient value is 0.9489140841521794
#
# Dice coeffecient value is 0.9530763416477702
#
# Dice coeffecient value is 0.9544570420760897
#
# Dice coeffecient value is 0.9571756109851348
#
# Dice coeffecient value is 0.9558956916099773
#
# Dice coeffecient value is 0.9585210380448476
#
# Dice coeffecient value is 0.9598715041572184
#
# Dice coeffecient value is 0.9663592844545226
#
# Dice coeffecient value is 0.9650440917107583
#
# Dice coeffecient value is 0.9637364575459814
#
# Dice coeffecient value is 0.961204333585286
#
# Dice coeffecient value is 0.9677676996724616
#
# Dice coeffecient value is 0.970204081632653
#
# Dice coeffecient value is 0.9690148652053414
#
# Dice coeffecient value is 0.9624263038548753
#
# Dice coeffecient value is 0.9806979087931469
#
# Dice coeffecient value is 0.9754396573444193
#
# Dice coeffecient value is 0.9792794154698916
#
# Dice coeffecient value is 0.9727790375409423
#
# Dice coeffecient value is 0.9766691861929957
#
# Dice coeffecient value is 0.9780146132527084
#
# Dice coeffecient value is 0.9740639959687579
#
# Dice coeffecient value is 0.9714512471655329
#
# Dice coeffecient value is 0.9821012849584279
#
# Dice coeffecient value is 0.9834744268077601
#
# Dice coeffecient value is 0.984771982867221
#
# Dice coeffecient value is 0.9862459057697153
#
# Dice coeffecient value is 0.9899042579994961
#
# Dice coeffecient value is 0.9873746535651298
#
# Dice coeffecient value is 0.992562358276644
#
# Dice coeffecient value is 0.9912471655328798
#
# Dice coeffecient value is 0.9938246409674981
#
# Dice coeffecient value is 0.9886999244142102
#
# Dice coeffecient value is 0.995028974552784
#
# Dice coeffecient value is 0.9959712773998488
#
# Dice coeffecient value is 0.9969035021415974
#
# Dice coeffecient value is 0.9983371126228269
#
# Dice coeffecient value is 0.9977878558830939
#
# Dice coeffecient value is 0.9985789871504157
#
# Dice coeffecient value is 0.9985638699924414
#
# Dice coeffecient value is 0.9985689090450995
#
# Dice coeffecient value is 0.9985789871504157
#
# Dice coeffecient value is 0.9985638699924414
#
# Dice coeffecient value is 0.9985537918871252
#
# Dice coeffecient value is 0.9985487528344671
#
# Dice coeffecient value is 0.9984303350970017
#
# Dice coeffecient value is 0.9984530108339632
#
# Dice coeffecient value is 0.9985084404132023
#
# Dice coeffecient value is 0.9984353741496599
#
# Dice coeffecient value is 0.9984303350970017
#
# Dice coeffecient value is 0.9984328546233309
#
# Dice coeffecient value is 0.998490803728899
#
# Dice coeffecient value is 0.9985109599395313
#
# Dice coeffecient value is 0.9984076593600403
#
# Dice coeffecient value is 0.9983698664651045
#
# Dice coeffecient value is 0.9982791635172588
#
# Dice coeffecient value is 0.9983824640967498
#
# Dice coeffecient value is 0.998392542202066
#
# Dice coeffecient value is 0.9982489292013101
#
# Dice coeffecient value is 0.9982791635172588
#
# Dice coeffecient value is 0.9943663391282439
#
# Dice coeffecient value is 0.9946989166036785
#
# Dice coeffecient value is 0.9983471907281432
#
# Dice coeffecient value is 0.9983068783068783
#
# Dice coeffecient value is 0.9526051902242378
#
# Dice coeffecient value is 0.9877676996724616
#
# Dice coeffecient value is 0.9832804232804233
#
# Dice coeffecient value is 0.9781078357268833
#
# Dice coeffecient value is 0.9899118165784833
#
# Dice coeffecient value is 0.8909800957420005
#
# Dice coeffecient value is 0.968044847568657
#
# Dice coeffecient value is 0.9325245653817082
#
# Dice coeffecient value is 0.8547543461829176
#
# Dice coeffecient value is 0.8196019148400101
#
# Dice coeffecient value is 0.810599647266314
#
# Dice coeffecient value is 0.7617762660619803
#
# Dice coeffecient value is 0.760501385739481
#
# Dice coeffecient value is 0.7929755605946082
#
# Dice coeffecient value is 0.7744343663391282
#
# Dice coeffecient value is 0.7604761904761905
#
# Dice coeffecient value is 0.7600579491055681
#
# Dice coeffecient value is 0.7662685815066768
#
# Dice coeffecient value is 0.7511766187956664
#
# Dice coeffecient value is 0.7700100781053162
#
# Dice coeffecient value is 0.7721441169060217
#
# Dice coeffecient value is 0.7793373645754598
#
# Dice coeffecient value is 0.7900302343159487
#
# Dice coeffecient value is 0.784870244394054
#
# Dice coeffecient value is 0.7749407911312673
#
# Dice coeffecient value is 0.7982111363063744
#
# Dice coeffecient value is 0.8266540690350214
#
# Dice coeffecient value is 0.810854119425548
#
# Dice coeffecient value is 0.848946837994457
#
# Dice coeffecient value is 0.8788788107835727
#
# Dice coeffecient value is 0.9044897959183673
#
# Dice coeffecient value is 0.9330713025951122
#
# Dice coeffecient value is 0.9976341647770219
#
# Dice coeffecient value is 0.9895742000503905
#
# Dice coeffecient value is 0.9643537414965987
#
# Dice coeffecient value is 0.9977878558830939
#
# Dice coeffecient value is 0.9997908793146888
#
# Dice coeffecient value is 0.9976593600403124
#
# Dice coeffecient value is 0.9986369362559838
#
# Dice coeffecient value is 0.9976240866717058
#
# Dice coeffecient value is 0.997687074829932
#
# Dice coeffecient value is 0.9979491055681532
#
# Dice coeffecient value is 0.994572940287226
#
# Dice coeffecient value is 0.9910884353741497
#
# Dice coeffecient value is 0.995222978080121
#
# Dice coeffecient value is 0.9963416477702192
#
# Dice coeffecient value is 0.9860241874527589
#
# Dice coeffecient value is 0.9765734441924918
#
# Dice coeffecient value is 0.9580020156210632
#
# Dice coeffecient value is 0.9434744268077602
#
# Dice coeffecient value is 0.924474678760393
#
# Dice coeffecient value is 0.9036457545981356
#
# Dice coeffecient value is 0.8355983875031494
#
# Dice coeffecient value is 0.8157545981355505
#
# Dice coeffecient value is 0.7966893424036281
#
# Dice coeffecient value is 0.8550491307634165
#
# Dice coeffecient value is 0.798190980095742
#
# Dice coeffecient value is 0.7995893172083648
#
# Dice coeffecient value is 0.8007281431090955
#
# Dice coeffecient value is 0.8021441169060217
#
# Dice coeffecient value is 0.7977072310405644
#
# Dice coeffecient value is 0.7978710002519527
#
# Dice coeffecient value is 0.7997430083144369
#
# Dice coeffecient value is 0.7992139077853364
#
# Dice coeffecient value is 0.800199042579995
#
# Dice coeffecient value is 0.8
#
# Dice coeffecient value is 0.7984051398337113
#
# Dice coeffecient value is 0.7976845553036029
#
# Dice coeffecient value is 0.7987755102040817
#
# Dice coeffecient value is 0.798538674729151
#
# Dice coeffecient value is 0.801158982111363
#
# Dice coeffecient value is 0.8046586041824138
#
# Dice coeffecient value is 0.8076971529352481
#
# Dice coeffecient value is 0.8087377173091459
#
# Dice coeffecient value is 0.8098639455782313
#
# Dice coeffecient value is 0.8135021415973797
#
# Dice coeffecient value is 0.8196900982615268
#
# Dice coeffecient value is 0.8161980347694633
#
# Dice coeffecient value is 0.8244570420760897
#
# Dice coeffecient value is 0.830604686318972
#
# Dice coeffecient value is 0.8369866465104561
#
# Dice coeffecient value is 0.8441572184429327
#
# Dice coeffecient value is 0.8523078861174099
#
# Dice coeffecient value is 0.8604232804232804
#
# Dice coeffecient value is 0.8703854875283447
#
# Dice coeffecient value is 0.8784126984126984
#
# Dice coeffecient value is 0.8859385235575712
#
# Dice coeffecient value is 0.8935903250188965
#
# Dice coeffecient value is 0.9028621819098009
#
# Dice coeffecient value is 0.9233484504913076
#
# Dice coeffecient value is 0.9328420256991685
#
# Dice coeffecient value is 0.9137037037037037
#
# Dice coeffecient value is 0.9529100529100529
#
# Dice coeffecient value is 0.9427865961199294
#
# Dice coeffecient value is 0.9627185689090451
#
# Dice coeffecient value is 0.974018644494835
#
# Dice coeffecient value is 0.9973444192491812
#
# Dice coeffecient value is 0.985175107079869
#
# Dice coeffecient value is 0.9978231292517007
#
# Dice coeffecient value is 0.9990123456790123
#
# Dice coeffecient value is 0.9983623078861175
#
# Dice coeffecient value is 0.9980851599899219
#
# Dice coeffecient value is 0.9982842025699169
#
# Dice coeffecient value is 0.9888485764676241
#
# Dice coeffecient value is 0.9889543965734442
#
# Dice coeffecient value is 0.9919702695893172
#
# Dice coeffecient value is 0.9968657092466616
#
# Dice coeffecient value is 0.9941546989166037
#
# Dice coeffecient value is 0.9935424540186445
#
# Dice coeffecient value is 0.9929251700680272
#
# Dice coeffecient value is 0.9922474174855127
#
# Dice coeffecient value is 0.9928546233308138
#
# Dice coeffecient value is 0.9936633912824389
#
# Dice coeffecient value is 0.9943436633912824
#
# Dice coeffecient value is 0.9878004535147392
#
# Dice coeffecient value is 0.9726706979087931
#
# Dice coeffecient value is 0.9369538926681784
#
# Dice coeffecient value is 0.9537314184933232
#
# Dice coeffecient value is 0.9085613504661124
#
# Dice coeffecient value is 0.8790753338372386
#
# Dice coeffecient value is 0.8491912320483749
#
# Dice coeffecient value is 0.8426706979087931
#
# Dice coeffecient value is 0.8364499874023683
#
# Dice coeffecient value is 0.8317460317460318
#
# Dice coeffecient value is 0.8347518266565885
#
# Dice coeffecient value is 0.8323305618543714
#
# Dice coeffecient value is 0.8308490803728898
#
# Dice coeffecient value is 0.8360922146636433
#
# Dice coeffecient value is 0.8427311665406904
#
# Dice coeffecient value is 0.8467346938775511
#
# Dice coeffecient value is 0.8561955152431343
#
# Dice coeffecient value is 0.8622323003275384
#
# Dice coeffecient value is 0.8726253464348702
#
# Dice coeffecient value is 0.9305820105820106
#
# Dice coeffecient value is 0.9461904761904761
#
# Dice coeffecient value is 0.9743033509700176
#
# Dice coeffecient value is 0.8994129503653313
#
# Dice coeffecient value is 0.9135802469135802
#
# Dice coeffecient value is 0.8851826656588562
#
# Dice coeffecient value is 0.9602242378432855
#
# Dice coeffecient value is 0.9855580750818846
#
# Dice coeffecient value is 0.9977122700932225
#
# Dice coeffecient value is 0.9937062232300328
#
# Dice coeffecient value is 0.9984958427815571
#
# Dice coeffecient value is 0.9922171831695641
#
# Dice coeffecient value is 0.9986041824137062
#
# Dice coeffecient value is 0.9976543209876543
#
# Dice coeffecient value is 0.9970143613000756
#
# Dice coeffecient value is 0.9383446712018141
#
# Dice coeffecient value is 0.9567447719828672
#
# Dice coeffecient value is 0.9702418745275888
#
# Dice coeffecient value is 0.9833585285966239
#
# Dice coeffecient value is 0.9204887881078357
#
# Dice coeffecient value is 0.9001612496850592
#
# Dice coeffecient value is 0.8837566137566137
#
# Dice coeffecient value is 0.7759637188208617
#
# Dice coeffecient value is 0.799543965734442
#
# Dice coeffecient value is 0.785474930713026
#
# Dice coeffecient value is 0.833116654069035
#
# Dice coeffecient value is 0.7867220962459057
#
# Dice coeffecient value is 0.8601637692113883
#
# Dice coeffecient value is 0.7933333333333333
#
# Dice coeffecient value is 0.7904812295288486
#
# Dice coeffecient value is 0.796633912824389
#
# Dice coeffecient value is 0.7927891156462585
#
# Dice coeffecient value is 0.795878054925674
#
# Dice coeffecient value is 0.7986117409926934
#
# Dice coeffecient value is 0.7935752078609222
#
# Dice coeffecient value is 0.7920508944318468
#
# Dice coeffecient value is 0.8020710506424792
#
# Dice coeffecient value is 0.8102645502645502
#
# Dice coeffecient value is 0.7949080372889896
#
# Dice coeffecient value is 0.8048475686570925
#
# Dice coeffecient value is 0.8391106072058453
#
# Dice coeffecient value is 0.8312723607961703
#
# Dice coeffecient value is 0.8553968253968254
#
# Dice coeffecient value is 0.8243033509700176
#
# Dice coeffecient value is 0.9267498110355253
#
# Dice coeffecient value is 0.9031065759637188
#
# Dice coeffecient value is 0.9470622323003275
#
# Dice coeffecient value is 0.815726883345931
#
# Dice coeffecient value is 0.8760871756109851
#
# Dice coeffecient value is 0.9654497354497354
#
# Dice coeffecient value is 0.9942831947593852
#
# Dice coeffecient value is 0.9117409926933736
#
# Dice coeffecient value is 0.8273041068279163
#
# Dice coeffecient value is 0.8654799697656841
#
# Dice coeffecient value is 0.9981985386747292
#
# Dice coeffecient value is 0.9826354245401865
#
# Dice coeffecient value is 0.8500100781053161
#
# Dice coeffecient value is 0.8383119173595364
#
# Dice coeffecient value is 0.9982338120433358
#
# Dice coeffecient value is 0.8906601158982111
#
# Dice coeffecient value is 0.8203628117913833
#
# Dice coeffecient value is 0.829952128999748
#
# Dice coeffecient value is 0.8278634416729654
#
# Dice coeffecient value is 0.8171428571428572
#
# Dice coeffecient value is 0.8147518266565885
#
# Dice coeffecient value is 0.8236911060720584
#
# Dice coeffecient value is 0.8311917359536407
#
# Dice coeffecient value is 0.8331443688586546
#
# Dice coeffecient value is 0.8350088183421517
#
# Dice coeffecient value is 0.8384882842025699
#
# Dice coeffecient value is 0.8403703703703703
#
# Dice coeffecient value is 0.8407583774250441
#
# Dice coeffecient value is 0.8426001511715797
#
# Dice coeffecient value is 0.8419223985890653
#
# Dice coeffecient value is 0.8481380700428319
#
# Dice coeffecient value is 0.8428294280675233
#
# Dice coeffecient value is 0.8447392290249434
#
# Dice coeffecient value is 0.846835474930713
#
# Dice coeffecient value is 0.8430461073318216
#
# Dice coeffecient value is 0.8506853111615016
#
# Dice coeffecient value is 0.8542504409171076
#
# Dice coeffecient value is 0.8604459561602419
#
# Dice coeffecient value is 0.8573847316704459
#
# Dice coeffecient value is 0.8641421012849584
#
# Dice coeffecient value is 0.8674200050390527
#
# Dice coeffecient value is 0.8741043083900226
#
# Dice coeffecient value is 0.8776795162509449
#
# Dice coeffecient value is 0.8705467372134039
#
# Dice coeffecient value is 0.8821365583270345
#
# Dice coeffecient value is 0.8876643990929706
#
# Dice coeffecient value is 0.8940060468631897
#
# Dice coeffecient value is 0.9092214663643235
#
# Dice coeffecient value is 0.9012093726379441
#
# Dice coeffecient value is 0.9235651297556059
#
# Dice coeffecient value is 0.916732174351222
#
# Dice coeffecient value is 0.9308138070042832
#
# Dice coeffecient value is 0.9571730914588057
#
# Dice coeffecient value is 0.9480599647266313
#
# Dice coeffecient value is 0.9997152935248174
#
# Dice coeffecient value is 0.9390828924162258
#
# Dice coeffecient value is 0.9999395313681028
#
# Dice coeffecient value is 0.9999521289997481
#
# Dice coeffecient value is 1.0
#
# Dice coeffecient value is 0.9999697656840514
#
# Dice coeffecient value is 0.9999773242630385
#
# Dice coeffecient value is 1.0
#
# Dice coeffecient value is 1.0
#
# Dice coeffecient value is 0.9998463088939279
#
# Dice coeffecient value is 0.9987200806248425
#
# Dice coeffecient value is 0.9979491055681532
#
# Dice coeffecient value is 0.9885789871504157
#
# Dice coeffecient value is 0.991002771478962
#
# Dice coeffecient value is 0.9855908289241623
#
# Dice coeffecient value is 0.9824212648022171
#
# Dice coeffecient value is 0.9952431342907533
#
# Dice coeffecient value is 0.9791156462585034
#
# Dice coeffecient value is 0.9968934240362812
#
# Dice coeffecient value is 0.9668052406147645
#
# Dice coeffecient value is 0.9934517510707986
#
# Dice coeffecient value is 0.9738120433358528
#
# Dice coeffecient value is 0.8884076593600403
#
# Dice coeffecient value is 0.8708969513731418
#
# Dice coeffecient value is 0.8693902746283698
#
# Dice coeffecient value is 0.9203854875283447
#
# Dice coeffecient value is 0.9504988662131519
#
# Dice coeffecient value is 0.9418921642731166
#
# Dice coeffecient value is 0.8723859914336105
#
# Dice coeffecient value is 0.9586873267825649
#
# Dice coeffecient value is 0.9080977576215672
#
# Dice coeffecient value is 0.9317813051146384
#
# Dice coeffecient value is 0.8753892668178382
#
# Dice coeffecient value is 0.8807886117409927
#
# Dice coeffecient value is 0.8749710254472159
#
# Dice coeffecient value is 0.8737490551776266
#
# Dice coeffecient value is 0.882312925170068
#
# Dice coeffecient value is 0.8777928949357521
#
# Dice coeffecient value is 0.872915091962711
#
# Dice coeffecient value is 0.8819727891156462
#
# Dice coeffecient value is 0.8820912068531116
#
# Dice coeffecient value is 0.8815898211136306
#
# Dice coeffecient value is 0.8696371882086168
#
# Dice coeffecient value is 0.8778332073570169
#
# Dice coeffecient value is 0.8798639455782313
#
# Dice coeffecient value is 0.8746334089191232
#
# Dice coeffecient value is 0.8813328294280676
#
# Dice coeffecient value is 0.8762711010330058
#
# Dice coeffecient value is 0.8717082388510959
#
# Dice coeffecient value is 0.8674804736709498
#
# Dice coeffecient value is 0.8676946334089192
#
# Dice coeffecient value is 0.8667372134038801
#
# Dice coeffecient value is 0.8658931720836482
#
# Dice coeffecient value is 0.8651221970269589
#
# Dice coeffecient value is 0.8667120181405896
#
# Dice coeffecient value is 0.8655127236079617
#
# Dice coeffecient value is 0.8664726631393298
#
# Dice coeffecient value is 0.8668102796674225
#
# Dice coeffecient value is 0.8750314940791132
#
# Dice coeffecient value is 0.8680826404635928
#
# Dice coeffecient value is 0.8720660115898211
#
# Dice coeffecient value is 0.8765028974552784
#
# Dice coeffecient value is 0.8820005039052659
#
# Dice coeffecient value is 0.8761199294532628
#
# Dice coeffecient value is 0.8875736961451247
#
# Dice coeffecient value is 0.8837364575459814
#
# Dice coeffecient value is 0.880146132527085
#
# Dice coeffecient value is 0.8786772486772487
#
# Dice coeffecient value is 0.8948047367094986
#
# Dice coeffecient value is 0.8907079868984631
#
# Dice coeffecient value is 0.8992139077853364
#
# Dice coeffecient value is 0.9141118669690098
#
# Dice coeffecient value is 0.9085260770975057
#
# Dice coeffecient value is 0.9273746535651297
#
# Dice coeffecient value is 0.9036130007558579
#
# Dice coeffecient value is 0.9202973041068279
#
# Dice coeffecient value is 0.9419375157470395
#
# Dice coeffecient value is 0.9346661627614009
#
# Dice coeffecient value is 0.948644494834971
#
# Dice coeffecient value is 0.9559234063995968
#
# Dice coeffecient value is 0.9628243890148652
#
# Dice coeffecient value is 0.969954648526077
#
# Dice coeffecient value is 0.9905542957923911
#
# Dice coeffecient value is 0.9970269589317209
#
# Dice coeffecient value is 0.9839556563366088
#
# Dice coeffecient value is 0.9774452003023432
#
# Dice coeffecient value is 0.998490803728899
#
# Dice coeffecient value is 0.9984479717813051
#
# Dice coeffecient value is 0.9985537918871252
#
# Dice coeffecient value is 0.9985991433610482
#
# Dice coeffecient value is 0.9986495338876291
#
# Dice coeffecient value is 0.9988359788359789
#
# Dice coeffecient value is 0.9987074829931972
#
# Dice coeffecient value is 0.9988107835726884
#
# Dice coeffecient value is 0.9981305114638448
#
# Dice coeffecient value is 0.9219349962207105
#
# Dice coeffecient value is 0.9072159234063996
#
# Dice coeffecient value is 0.8976064499874024
#
# Dice coeffecient value is 0.8863668430335097
#
# Dice coeffecient value is 0.8745578231292517
#
# Dice coeffecient value is 0.8649130763416478
#
# Dice coeffecient value is 0.8575258251448727
#
# Dice coeffecient value is 0.8454169816074578
#
# Dice coeffecient value is 0.8502544721592341
#
# Dice coeffecient value is 0.9969261778785589
#
# Dice coeffecient value is 0.9968581506676745
#
# Dice coeffecient value is 0.9968909045099521
#
# Dice coeffecient value is 0.9965381708238851
#
# Dice coeffecient value is 0.9960745779793398
#
# Dice coeffecient value is 0.9955479969765684
#
# Dice coeffecient value is 0.9957470395565634
#
# Dice coeffecient value is 0.9954169816074578
#
# Dice coeffecient value is 0.9951095993953136
#
# Dice coeffecient value is 0.9953086419753087
#
# Dice coeffecient value is 0.9943587805492567
#
# Dice coeffecient value is 0.9948677248677249
#
# Dice coeffecient value is 0.9939103048626858
#
# Dice coeffecient value is 0.9936533131771227
#
# Dice coeffecient value is 0.9934416729654825
#
# Dice coeffecient value is 0.9930209120685312
#
# Dice coeffecient value is 0.9927034517510708
#
# Dice coeffecient value is 0.9925522801713278
#
# Dice coeffecient value is 0.9924389014865206
#
# Dice coeffecient value is 0.9921693121693121
#
# Dice coeffecient value is 0.9967548500881834
#
# Dice coeffecient value is 0.997087427563618
#
# Dice coeffecient value is 0.9971756109851347

# %%
dicee = np.array(dicee)

# %%
#len = len(dicee)
print("Number of Values is", len)

# Taking average of dice values
av=np.mean(dicee)
print ("average dice values is", av)

# Taking maximuim and minimuim of dice values
mx=np.max(dicee)
print ("maximuim dice values is", mx)

mn=np.min(dicee)
print ("minimuim dice values is", mn)
# Out:
# Number of Values is 829
# average dice values is 0.8937076911808373
# maximuim dice values is 1.0
# minimuim dice values is 0.7511766187956664
